# %% [markdown]
# #### 1. Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
customer_df = pd.read_csv('files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.shape)
display(customer_df.head())
display(customer_df.tail())
# Out:
# (9134, 24)
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# #### 3. First, look at its main features (head, shape, info).

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# #### 4. Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
def standardize_header(dataframe):
    dataframe.columns = [c.lower().replace(' ', '_') for c in dataframe.columns]

standardize_header(customer_df)

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# #### 5. Fix the data types of any other column/columns as you might see necessary.
# #### Change effective to date column to datetime format.

# %%
customer_df.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])

# %%
customer_df['effective_to_date'].head()
# Out:
# 0   2011-02-24
# 1   2011-01-31
# 2   2011-02-19
# 3   2011-01-20
# 4   2011-02-03
# Name: effective_to_date, dtype: datetime64[ns]

# %%
customer_df.dtypes
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %% [markdown]
# #### 6. Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
numerical = customer_df.select_dtypes(include=np.number)
numerical
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
for col in numerical.columns:
    print(len(numerical[col].unique()))
# Out:
# 8041
# 5694
# 202
# 36
# 100
# 6
# 9
# 5106

# %%
discrete_list = []
continuous_list = []
for col in numerical.columns:
    if len(numerical[col].unique()) < (customer_df.shape[0] * 0.03):
        discrete_list.append(col)
    else: 
        continuous_list.append(col)
display(discrete_list)
display(continuous_list)
# Out:
# ['monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies']
# ['customer_lifetime_value', 'income', 'total_claim_amount']

# %%
def c_d_dif(df):
    discrete_list = []
    continuous_list = []
    for col in df.columns:
        if len(df[col].unique()) < (customer_df.shape[0] * 0.03):
            discrete_list.append(col)
        else: 
            continuous_list.append(col)
    return discrete_list,continuous_list

# %%
discrete_list,continuous_list = c_d_dif(numerical)

# %%
discrete_list
# Out:
# ['monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies']

# %%
continuous_list
# Out:
# ['customer_lifetime_value', 'income', 'total_claim_amount']

# %%
discrete_df = numerical[discrete_list]
discrete_df
# Out:
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# 2                      108                       18
# 3                      106                       18
# 4                       73                       12
# ...                    ...                      ...
# 9129                    73                       18
# 9130                    79                       14
# 9131                    85                        9
# 9132                    96                       34
# 9133                    77                        3
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                 5                          0
# 1                                42                          0
# 2                                38                          0
# 3                                65                          0
# ...

# %%
continuous_df = numerical[continuous_list]
continuous_df
# Out:
#       customer_lifetime_value  income  total_claim_amount
# 0                 2763.519279   56274          384.811147
# 1                 6979.535903       0         1131.464935
# 2                12887.431650   48767          566.472247
# 3                 7645.861827       0          529.881344
# 4                 2813.692575   43836          138.130879
# ...                       ...     ...                 ...
# 9129             23405.987980   71941          198.234764
# 9130              3096.511217   21604          379.200000
# 9131              8163.890428       0          790.784983
# 9132              7524.442436   21941          691.200000
# 9133              2611.836866       0          369.600000
#
# [9134 rows x 3 columns]

# %% [markdown]
# #### 7. Plot a correlation matrix, comment what you see.

# %%
plt.figure(figsize = (20,15))
correlations_matrix = customer_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# All values are low corralated, just maybe total_claim_amount and monthly_premium_auto are a bit more correlated with 0.63 as well as monthly_premium_auto with customer_lifetime_value, so if we need to drop one column I would go for monthly_premium_auto as it have the highest correlation with 2 variables.

# %% [markdown]
# #### 8. Create a function to plot every discrete variable. Do the same with the continuous variables (Be Careful, you may need to change the plot type to one better suited for continuous data!)

# %%
# Discrete Variables Plots
plt.figure(figsize = (10,5))
for column in numerical[discrete_list]:
    sns.distplot(numerical[column])
    plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Continuous Variables Plots
plt.figure(figsize = (10,5))
for column in numerical[continuous_list]:
    sns.histplot(numerical[column])
    plt.show()

# %% [markdown]
# #### 9. Comment what you can see in the plots.

# %% [markdown]
# We can observe Outliers in discrete variables as "monthly_premium_auto" and in continuous variables as "customer_lifetime_value", "income" and "total_claim_amount".

# %% [markdown]
# #### 10. Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

# %%
# I am checking as well for the discrete where i found outliers. (monthly_premium_auto)
sns.boxplot(numerical['monthly_premium_auto'])
plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# I am checking for the continuous where i found outliers.
for column in numerical[continuous_list]:
    sns.boxplot(numerical[column])
    plt.show()
# Out:
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ChristianGardel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# #### 11. Did you find outliers? Comment what you will do with them.

# %%
# To deal with the Outliers we can just remove them with the iqr approach as in this example: 
iqr = np.percentile(numerical['monthly_premium_auto'],75) - np.percentile(numerical['monthly_premium_auto'],25)
upper_limit = np.percentile(numerical['monthly_premium_auto'],75) + 1.5*iqr
lower_limit = np.percentile(numerical['monthly_premium_auto'],25) - 1.5*iqr

# %%
no_outliers = numerical[(numerical['monthly_premium_auto']>lower_limit) & (numerical['monthly_premium_auto']<upper_limit)].copy()
sns.displot(no_outliers['monthly_premium_auto'])
plt.show()

# %% [markdown]
# #### 12. Check all columns for NaN values. Decide what (if anything) you will need to do with them.

# %%
customer_df.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# We dont have any NaN values in the data so no further action is required.
